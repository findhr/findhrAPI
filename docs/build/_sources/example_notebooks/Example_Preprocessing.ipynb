# %% [markdown]
# # Preprocessing
# This notebook shows an example of how to use the preprocessing APIs of findhr package on the sample data loaded from the Example_InputDataSources notebook.

# %%
# Load and join raw data sources and their metadata.
# %run Example_InputDataSources.ipynb

# %%
# Joined DataFrame.
df_all.head()
# Out:
#    id_c                             education_background_c  \
# 0     5  [{'institution': 'Complutense University Of Ma...
# 1     6  [{'institution': 'Coronel Rosales Agricultural...
# 2    10  [{'institution': 'Complutense University Of Ma...
# 3    11  [{'institution': 'Les Ribera De Los Molinos', ...
# 4    15  [{'institution': 'Escuela Politcnica Superior ...
#
#                            professional_experience_c  \
# 0  [{'institution': 'Stylo Milano', 'start_date':...
# 1  [{'institution': 'Securitas Direct', 'start_da...
# 2  [{'institution': 'Carrefour Express', 'start_d...
# 3  [{'institution': 'Decimas Sl', 'start_date': '...
# 4  [{'institution': 'Reintegrate', 'start_date': ...
#
#                                             skills_c gender_c  \
# 0  [Communications, Social Integration, Microsoft...      Man
# 1  [Refinancing, Economy, Microsoft Excel, Collec...      Man
# 2  [Entrepreneurship, Literacy, Web Design, Adobe...    Woman
# 3  [Consulting, Sap Crm, Collections, Automation,...    Woman
# 4  [Microsoft Word, Biofuels, English, Entreprene...      Man
#
#   agg_perceived_foreign_c  id_j  \
# 0                      No     5
# 1                      No     3
# 2                      No     5
# 3                      No     3
# 4                      No     3
#
#                                     education_reqs_j  \
# 0  [Law Bachelor, Degree In Law, Higher Degree In...
# 1                                                 []
# 2  [Law Bachelor, Degree In Law, Higher Degree In...
# 3                                                 []
# 4                                                 []
#
#                               experience_reqs_role_j  \
# 0                                       [Consultant]
# 1  [Sales Assistant, Saleswoman, Commercial Advisor]
# 2                                       [Consultant]
# 3  [Sales Assistant, Saleswoman, Commercial Advisor]
# 4  [Sales Assistant, Saleswoman, Commercial Advisor]
#
#    experience_reqs_duration_j  \
# 0                          12
# 1                          12
# 2                          12
# 3                          12
# 4                          12
#
#                                             skills_j gender_j  \
# 0  [Punctuality, Organization, Accounting, Englis...      Man
# 1  [English, Spanish, Communications, Communicati...      Man
# 2  [Punctuality, Organization, Accounting, Englis...      Man
# 3  [English, Spanish, Communications, Communicati...      Man
# 4  [English, Spanish, Communications, Communicati...      Man
#
#   agg_perceived_foreign_j     score  ranking  shortlisted
# 0                      No  0.000000      138            0
# 1                      No  0.000000       89            0
# 2                      No  0.492754       55            0
# 3                      No  0.492754       35            0
# 4                      No  0.453089       49            0

# %%
# Joined metadata.
md_all
# Out:
# {'id_c':
#  	SCHEMA = {'type': 'number'}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'education_background_c':
#  	SCHEMA = {'type': 'array', 'items': {'type': 'object', 'properties': {'institution': {'type': 'string'}, 'end_date': {'type': 'string'}, 'degree': {'type': 'string'}, 'duration': {'type': 'string'}}}}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'professional_experience_c':
#  	SCHEMA = {'type': 'array', 'items': {'type': 'object', 'properties': {'institution': {'type': 'string'}, 'end_date': {'type': 'string'}, 'role': {'type': 'string'}, 'duration': {'type': 'string'}}}}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'skills_c':
#  	SCHEMA = {'type': 'array', 'items': {'type': 'string'}}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'gender_c':
#  	SCHEMA = {'enum': ['Man', 'Woman', 'Any']}
#  	ATTR_TYPE = category
#  	ATTR_USAGE = sensitive
#  	KNOWLEDGE_BASE = None,
#  'agg_perceived_foreign_c':
#  	SCHEMA = {'enum': ['No', 'Yes', 'Any']}
#  	ATTR_TYPE = category
#  	ATTR_USAGE = sensitive
#  	KNOWLEDGE_BASE = None,
#  'id_j':
#  	SCHEMA = {'type': 'number'}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'education_reqs_j':
#  	SCHEMA = {'type': 'array', 'items': {'type': 'string'}}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'experience_reqs_role_j':
#  	SCHEMA = {'type': 'array', 'items': {'type': 'string'}}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'experience_reqs_duration_j':
#  	SCHEMA = {'type': 'number'}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'skills_j':
#  	SCHEMA = {'type': 'array', 'items': {'type': 'string'}}
#  	ATTR_TYPE = object
#  	ATTR_USAGE = default
#  	KNOWLEDGE_BASE = None,
#  'gender_j':
#  	SCHEMA = {'enum': ['Man', 'Woman', 'Any']}
#  	ATTR_TYPE = category
#  	ATTR_USAGE = sensitive
#  	KNOWLEDGE_BASE = None,
#  'agg_perceived_foreign_j':
#  	SCHEMA = {'enum': ['No', 'Yes', 'Any']}
#  	ATTR_TYPE = category
#  	ATTR_USAGE = sensitive
#  	KNOWLEDGE_BASE = None,
#  'score':
#  	SCHEMA = {'type': 'number'}
#  	ATTR_TYPE = numeric
#  	ATTR_USAGE = target
#  	KNOWLEDGE_BASE = None,
#  'ranking':
#  	SCHEMA = {'type': 'integer'}
#  	ATTR_TYPE = ordinal
#  	ATTR_USAGE = target
#  	KNOWLEDGE_BASE = None,
#  'shortlisted':
#  	SCHEMA = {'type': 'integer'}
#  	ATTR_TYPE = category
#  	ATTR_USAGE = target
#  	KNOWLEDGE_BASE = None}

# %%
# Setting category columns in DataFrame based on metadata.
cat_cols = [k for k, v in md_all.items() if v.attr_type=='category']
df_all[cat_cols] = df_all[cat_cols].astype('category')
# Dataframe metadata.
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643 entries, 0 to 1642
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_c                        1643 non-null   int64
#  1   education_background_c      1643 non-null   object
#  2   professional_experience_c   1643 non-null   object
#  3   skills_c                    1643 non-null   object
#  4   gender_c                    1643 non-null   category
#  5   agg_perceived_foreign_c     1643 non-null   category
#  6   id_j                        1643 non-null   int64
#  7   education_reqs_j            1643 non-null   object
#  8   experience_reqs_role_j      1643 non-null   object
#  9   experience_reqs_duration_j  1643 non-null   int64
#  10  skills_j                    1643 non-null   object
#  11  gender_j                    1643 non-null   category
#  12  agg_perceived_foreign_j     1643 non-null   category
#  13  score                       1643 non-null   float64
#  14  ranking                     1643 non-null   int64
#  15  shortlisted                 1643 non-null   category
# dtypes: category(5), float64(1), int64(4), object(6)
# memory usage: 149.9+ KB

# %%
# Define ids, target feature(s), and predictive features.
id_cols = ['id_c', 'id_j']
target_cols = ['score', 'ranking', 'shortlisted']
pred_cols = df_all.columns.difference(target_cols + id_cols)

# %%
df_ADS
# Out:
#       id_c  id_j     score  ranking  shortlisted
# 0        6     3  0.000000       89            0
# 1       11     3  0.492754       35            0
# 3       15     3  0.453089       49            0
# 4       17     3  0.049689       81            0
# 5       19     3  0.080268       78            0
# ...    ...   ...       ...      ...          ...
# 1537  2204     1  0.550725       44            0
# 1538  2211     1  0.550725       44            0
# 1539  2213     1  0.478261      123            0
# 1540  2214     1  0.478261      123            0
# 1541  2215     1  0.455243      145            0
#
# [1643 rows x 5 columns]

# %%
# Derived column transformations.
from findhr.preprocess.example_mappings import RelevantExperienceForRole, ExtractMonthDurationJob, MatchOrdinal, ExtractListOfProperty, MatchFeatureAtLeastInList, MatchFeatureSet, MatchBinary

# Calculated features.
maps_derived_1 = {
    (('professional_experience_c', 'experience_reqs_role_j',), ('relevant_exp_role_c',)): RelevantExperienceForRole(),
}

maps_derived_2 = {
        (('relevant_exp_role_c',), ('role_duration_months_c',)): ExtractMonthDurationJob(duration_key='duration_months'),
        (('education_background_c',), ('degree_list_c',)): ExtractListOfProperty(property_key='degree')
}

# Fitness features about the matching between candidate's features and job's requirements.
maps_matching = {
    (('experience_reqs_duration_j', 'role_duration_months_c'), ('fitness_experience',)): MatchOrdinal(),
    (('education_reqs_j', 'education_background_c'), ('fitness_education',)): MatchFeatureAtLeastInList(),
    (('skills_j', 'skills_c'), ('fitness_skills',)): MatchFeatureSet(),
    (('gender_j', 'gender_c'), ('fitness_gender',)): MatchBinary(),
    (('agg_perceived_foreign_j', 'agg_perceived_foreign_c'), ('fitness_foreign',)): MatchBinary()
}

# Helper variable for the fitness features
list_cols_fitness = ['fitness_experience', 'fitness_education', 'fitness_skills', 'fitness_gender', 'fitness_foreign']
maps_matching
# Out:
# {(('experience_reqs_duration_j', 'role_duration_months_c'),
#   ('fitness_experience',)): MatchOrdinal(),
#  (('education_reqs_j', 'education_background_c'),
#   ('fitness_education',)): MatchFeatureAtLeastInList(),
#  (('skills_j', 'skills_c'), ('fitness_skills',)): MatchFeatureSet(),
#  (('gender_j', 'gender_c'), ('fitness_gender',)): MatchBinary(),
#  (('agg_perceived_foreign_j', 'agg_perceived_foreign_c'),
#   ('fitness_foreign',)): MatchBinary()}

# %%
# Scikit-learn transformation for numeric and categorical features
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.compose import ColumnTransformer

numeric_features = list_cols_fitness
categorical_features = ['gender_c', 'agg_perceived_foreign_c']
# imputing and scaling numeric features
numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")), # Not needed for the used dataset.
        ("scaler", StandardScaler()) # Not needed for the decision tree, let's keep it for the sake of generality.
    ]
)
# imputing and encoding categorical features
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")), # Not needed for the used dataset, again for the sake of generality.
        ("encoder", OneHotEncoder()), # Convert to one-hot encoding
    ]
)
# combining the two above
column_preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
   ]
)

# %%
from findhr.preprocess.mapping import AttachMetadata, DetachMetadata, DerivedColumn
# The pipeline is composed of two phases:
# 1. Preprocessing with metadata (using findhr package)
pipeline_derived = Pipeline(steps=[
    ("init", AttachMetadata(md_all)),
    ('mapping_1', DerivedColumn(maps_derived_1, verbose=True)),
    ('mapping_2', DerivedColumn(maps_derived_2, verbose=True)),
    ("matching", DerivedColumn(maps_matching, verbose=True)),
    # ("fitness", GroundTruthLinearWeightedScorer(gt_weights_fair)),
    ("end", DetachMetadata())
])
# 2. Standard scikit-learn preprocessing to prepare the data for the model covered by column preprocessor.

# %%
# Complete preprocessing pipeline.
pipeline_pre = Pipeline(
    steps=[
        # first phase: preprocessing with metadata
        ('fitness_value', pipeline_derived),
        # second phase: preprocessing without metadata (standard scikit-learn)
        ("column_preprocessor", column_preprocessor)
       ]
)
# Pipeline for regression model on the target feature "score".
pipeline_regr = Pipeline(
    steps=[
        # preprocessing with metadata
        ("preprocessing", pipeline_pre),
        # model inference
        ("regressor", DecisionTreeRegressor(max_depth=3))
       ]
)

# %%
# Model fit.
pipeline_regr.fit(df_all.loc[:, pred_cols], df_all.loc[:, 'score'])
# Out:
# Fitting mapping RelevantExperienceForRole for input columns ('professional_experience_c', 'experience_reqs_role_j') and output columns ('relevant_exp_role_c',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j'],
#       dtype='object')
# Fitting mapping ExtractMonthDurationJob for input columns ('relevant_exp_role_c',) and output columns ('role_duration_months_c',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c'],
#       dtype='object')
# Fitting mapping ExtractListOfProperty for input columns ('education_background_c',) and output columns ('degree_list_c',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c'],
#       dtype='object')
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Ies Arinaga Crossing', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Ies Pea Del Aguila', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Ies Pea Del Aguila', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Sant Ferran School', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of Buenos Aires', 'start_date': 'January 2008', 'end_date': 'December 2013', 'degree': 'Bachelor Of Arts Linguistics Orientation'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Estuaria Secondary Education Institute', 'start_date': 'January 1998', 'end_date': 'December 1998', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Ies Arinaga Crossing', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Lund University', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Higher School Preparatory Classes', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Lund University', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Alcala De Henares', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Alcala De Henares', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'University Of Copenhagen', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}]
# list_dict = [{'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of The Armed Forces  Espe', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of The Armed Forces  Espe', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Unan', 'start_date': 'January 2019', 'end_date': 'December 2023', 'degree': 'Information Systems Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'University Of Valladolid ', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'Politecnic University of Valencia', 'start_date': 'January 2003', 'end_date': 'December 2003', 'degree': 'Engineering In Industrial Organization'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2017', 'end_date': 'December 2019', 'degree': 'Master In Mathematical Engineering'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Uppsala University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Phd In Computer Science Ongoing'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'Politecnic University of Valencia', 'start_date': 'January 2003', 'end_date': 'December 2003', 'degree': 'Engineering In Industrial Organization'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'University Of Helsinki', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'University Of Helsinki', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'University Of Stavanger', 'start_date': 'August 2018', 'end_date': 'May 2020', 'degree': 'Msc In Computer Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'University Of Helsinki', 'start_date': 'August 2018', 'end_date': 'May 2020', 'degree': 'Msc In Computer Science'}, {'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Copenhagen', 'start_date': 'September 2013', 'end_date': 'December 2015', 'degree': 'Msc in Nanoscience'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Copenhagen', 'start_date': 'September 2013', 'end_date': 'December 2015', 'degree': 'Msc in Nanoscience'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# ...
# list_dict = [{'institution': 'Universidad De Alcala De Henares', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Universidad De Alcala De Henares', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'University College London Ucl', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# Fitting mapping MatchOrdinal for input columns ('experience_reqs_duration_j', 'role_duration_months_c') and output columns ('fitness_experience',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchFeatureAtLeastInList for input columns ('education_reqs_j', 'education_background_c') and output columns ('fitness_education',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchFeatureSet for input columns ('skills_j', 'skills_c') and output columns ('fitness_skills',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchBinary for input columns ('gender_j', 'gender_c') and output columns ('fitness_gender',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchBinary for input columns ('agg_perceived_foreign_j', 'agg_perceived_foreign_c') and output columns ('fitness_foreign',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('fitness_value',
#                                   Pipeline(steps=[('init',
#                                                    AttachMetadata(metadata_dict={'agg_perceived_foreign_c':
# 	SCHEMA = {'enum': ['No', 'Yes', 'Any']}
# 	ATTR_TYPE = category
# 	ATTR_USAGE = sensitive
# 	KNOWLEDGE_BASE = None,
#                                                                                  'agg_perceived_foreign_j':
# 	SCHEMA = {'enum': ['No', 'Yes', 'Any']}
# 	ATTR_TYPE = category
# 	ATTR_USAGE = sensitive
# 	KNOWLEDGE_BASE...
#                                                                                     SimpleImputer(strategy='median')),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['fitness_experience',
#                                                                     'fitness_education',
#                                                                     'fitness_skills',
#                                                                     'fitness_gender',
#                                                                     'fitness_foreign']),
#                                                                   ('cat',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('encoder',
#                                                                                     OneHotEncoder())]),
#                                                                    ['gender_c',
#                                                                     'agg_perceived_foreign_c'])]))])),
#                 ('regressor', DecisionTreeRegressor(max_depth=3))])

# %%
transformed_data = pipeline_pre.fit_transform(df_all.loc[:, pred_cols])
pd.DataFrame(transformed_data).describe()
# Out:
# Fitting mapping RelevantExperienceForRole for input columns ('professional_experience_c', 'experience_reqs_role_j') and output columns ('relevant_exp_role_c',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j'],
#       dtype='object')
# Fitting mapping ExtractMonthDurationJob for input columns ('relevant_exp_role_c',) and output columns ('role_duration_months_c',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c'],
#       dtype='object')
# Fitting mapping ExtractListOfProperty for input columns ('education_background_c',) and output columns ('degree_list_c',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c'],
#       dtype='object')
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Ies Arinaga Crossing', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Ies Pea Del Aguila', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Ies Pea Del Aguila', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Sant Ferran School', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of Buenos Aires', 'start_date': 'January 2008', 'end_date': 'December 2013', 'degree': 'Bachelor Of Arts Linguistics Orientation'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Estuaria Secondary Education Institute', 'start_date': 'January 1998', 'end_date': 'December 1998', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Ies Arinaga Crossing', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Lund University', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Higher School Preparatory Classes', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Lund University', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Alcala De Henares', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Alcala De Henares', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'University Of Copenhagen', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}]
# list_dict = [{'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of The Armed Forces  Espe', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of The Armed Forces  Espe', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Unan', 'start_date': 'January 2019', 'end_date': 'December 2023', 'degree': 'Information Systems Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'University Of Valladolid ', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'Politecnic University of Valencia', 'start_date': 'January 2003', 'end_date': 'December 2003', 'degree': 'Engineering In Industrial Organization'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2017', 'end_date': 'December 2019', 'degree': 'Master In Mathematical Engineering'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Uppsala University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Phd In Computer Science Ongoing'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'Politecnic University of Valencia', 'start_date': 'January 2003', 'end_date': 'December 2003', 'degree': 'Engineering In Industrial Organization'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'University Of Helsinki', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'University Of Helsinki', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'University Of Stavanger', 'start_date': 'August 2018', 'end_date': 'May 2020', 'degree': 'Msc In Computer Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'University Of Helsinki', 'start_date': 'August 2018', 'end_date': 'May 2020', 'degree': 'Msc In Computer Science'}, {'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Copenhagen', 'start_date': 'September 2013', 'end_date': 'December 2015', 'degree': 'Msc in Nanoscience'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Copenhagen', 'start_date': 'September 2013', 'end_date': 'December 2015', 'degree': 'Msc in Nanoscience'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# ...
# list_dict = [{'institution': 'Nust School Of Electrical Engineering And Computer Science', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Universidad De Alcala De Henares', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Universidad De Alcala De Henares', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'University College London Ucl', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# Fitting mapping MatchOrdinal for input columns ('experience_reqs_duration_j', 'role_duration_months_c') and output columns ('fitness_experience',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchFeatureAtLeastInList for input columns ('education_reqs_j', 'education_background_c') and output columns ('fitness_education',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchFeatureSet for input columns ('skills_j', 'skills_c') and output columns ('fitness_skills',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchBinary for input columns ('gender_j', 'gender_c') and output columns ('fitness_gender',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
# Fitting mapping MatchBinary for input columns ('agg_perceived_foreign_j', 'agg_perceived_foreign_c') and output columns ('fitness_foreign',)
# X.columns = Index(['agg_perceived_foreign_c', 'agg_perceived_foreign_j',
#        'education_background_c', 'education_reqs_j',
#        'experience_reqs_duration_j', 'experience_reqs_role_j', 'gender_c',
#        'gender_j', 'professional_experience_c', 'skills_c', 'skills_j',
#        'relevant_exp_role_c', 'role_duration_months_c', 'degree_list_c'],
#       dtype='object')
#                   0             1             2             3             4  \
# count  1.643000e+03  1.643000e+03  1.643000e+03  1.643000e+03  1.643000e+03
# mean   6.270767e-17  4.757133e-17  3.459733e-17  7.784400e-17  2.162333e-18
# std    1.000304e+00  1.000304e+00  1.000304e+00  1.000304e+00  1.000304e+00
# min   -3.583770e-01 -2.435499e-01 -1.223200e+00 -9.623632e-01 -2.678457e+00
# 25%   -3.583770e-01 -2.435499e-01 -7.784247e-01 -9.623632e-01  3.733493e-01
# 50%   -3.583770e-01 -2.435499e-01 -3.336493e-01 -9.623632e-01  3.733493e-01
# 75%   -3.583770e-01 -2.435499e-01  5.559016e-01  1.039109e+00  3.733493e-01
# max    2.790358e+00  4.105934e+00  3.224554e+00  1.039109e+00  3.733493e-01
#
#                  5            6            7            8
# count  1643.000000  1643.000000  1643.000000  1643.000000
# mean      0.480828     0.519172     0.877663     0.122337
# std       0.499784     0.499784     0.327775     0.327775
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000     0.000000
# 50%       0.000000     1.000000     1.000000     0.000000
# 75%       1.000000     1.000000     1.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000

# %%
# Model prediction.
pipeline_regr.predict(df_all.loc[:, pred_cols])
# Out:
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Ies Arinaga Crossing', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Ies Pea Del Aguila', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Icade University Of Comillas', 'start_date': 'January 1985', 'end_date': 'December 1986', 'degree': 'Graduated In Marketing And Commercial Management'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Escuela Politcnica Superior De Lugo', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Les Ribera De Los Molinos', 'start_date': 'January 2016', 'end_date': 'December 2020', 'degree': 'Degree In Aesthetics And Beauty'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Coronel Rosales Agricultural School', 'start_date': 'January 1988', 'end_date': 'December 1993', 'degree': 'Agricultural Technical Engineer'}]
# list_dict = [{'institution': 'Ies Pea Del Aguila', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Lmu', 'start_date': 'October 2017', 'end_date': 'April 2019', 'degree': 'International Master Program in german'}, {'institution': 'Sant Ferran School', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of Buenos Aires', 'start_date': 'January 2008', 'end_date': 'December 2013', 'degree': 'Bachelor Of Arts Linguistics Orientation'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Estuaria Secondary Education Institute', 'start_date': 'January 1998', 'end_date': 'December 1998', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of The Basque Country', 'start_date': 'January 1996', 'end_date': 'December 1996', 'degree': 'Secondary Education Degree'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'Ies Arinaga Crossing', 'start_date': 'September 2017', 'end_date': 'June 2021', 'degree': 'Eso Graduate'}]
# list_dict = [{'institution': 'Complutense University Of Madrid', 'start_date': 'January 2023', 'end_date': 'Ongoing', 'degree': 'Degree In Law'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Lund University', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Higher School Preparatory Classes', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Lund University', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Alcala De Henares', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Alcala De Henares', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'University Of Copenhagen', 'start_date': 'January 2016', 'end_date': 'December 2018', 'degree': 'Master Of Science In Physics'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}]
# list_dict = [{'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of The Armed Forces  Espe', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of The Armed Forces  Espe', 'start_date': 'January 2011', 'end_date': 'December 2017', 'degree': 'Geographical And Environmental Engineer'}]
# list_dict = [{'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Unan', 'start_date': 'January 2019', 'end_date': 'December 2023', 'degree': 'Information Systems Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Politehnica University Of Timisoara', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'The Briedge School', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'University Of Valladolid ', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'Politecnic University of Valencia', 'start_date': 'January 2003', 'end_date': 'December 2003', 'degree': 'Engineering In Industrial Organization'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Valencia', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Politecnico Di Torino', 'start_date': 'September 2017', 'end_date': 'December 2019', 'degree': 'Master In Mathematical Engineering'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Uppsala University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Phd In Computer Science Ongoing'}, {'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'Politecnic University of Valencia', 'start_date': 'January 2003', 'end_date': 'December 2003', 'degree': 'Engineering In Industrial Organization'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'January 2023', 'end_date': 'Current', 'degree': 'Master Data Science'}, {'institution': 'University Of Helsinki', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'University Of Helsinki', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}, {'institution': 'Radboud University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'University Of Stavanger', 'start_date': 'August 2018', 'end_date': 'May 2020', 'degree': 'Msc In Computer Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'September 2016', 'end_date': 'June 2020', 'degree': 'Bachelor In Computer Engineering'}]
# list_dict = [{'institution': 'Elbs', 'start_date': 'October 2020', 'end_date': 'November 2020', 'degree': 'Expert Master in Chromotography'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2013', 'end_date': 'December 2017', 'degree': 'Bachelor Of Sciences And Letters'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'University Of Alicante', 'start_date': 'January 2019', 'end_date': 'December 2020', 'degree': 'Master In Natural Risk Planning And Management'}, {'institution': 'Pierre Et Marie Curie University Sorbonne University', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Universiteit Van Amsterdam', 'start_date': 'September 2020', 'end_date': 'June 2022', 'degree': 'Master Social Sciences Research'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Humboldt University Of Berlin', 'start_date': 'October 2018', 'end_date': 'September 2021', 'degree': 'Master Of Science In Psychology'}, {'institution': 'Politecnico Di Torino', 'start_date': 'September 2014', 'end_date': 'October 2017', 'degree': 'Bs In Mathematical Engineering'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Seville', 'start_date': 'January 2020', 'end_date': 'December 2021', 'degree': 'Masters Degree In Teaching In Compulsory Secondary Education Baccalaureate Vocational Training And Language Teaching'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'October 2009', 'end_date': 'July 2012', 'degree': 'Bsc in Physics and Computer Science'}]
# list_dict = [{'institution': 'Stanford University', 'start_date': 'January 2016', 'end_date': 'December 2016', 'degree': 'Master Of Arts Ma Education'}, {'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'University Of Helsinki', 'start_date': 'August 2018', 'end_date': 'May 2020', 'degree': 'Msc In Computer Science'}, {'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Copenhagen', 'start_date': 'September 2013', 'end_date': 'December 2015', 'degree': 'Msc in Nanoscience'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'University Of Copenhagen', 'start_date': 'September 2013', 'end_date': 'December 2015', 'degree': 'Msc in Nanoscience'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'December 2007', 'end_date': 'January 2012', 'degree': 'Bachelor Comoputer Science'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University', 'start_date': 'September 2020', 'end_date': 'Current', 'degree': 'Master In Data Science'}, {'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Western Norway University Of Applied Sciences', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'Commercial College Of The West', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Alexandru Ioan Cuza University', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'August 2020', 'end_date': 'June 2022', 'degree': 'Msc In Computer Science  Data Science'}, {'institution': 'University Of Zurich', 'start_date': 'October 2013', 'end_date': 'September 2016', 'degree': 'Bsc In Applied Computer Science'}]
# list_dict = [{'institution': 'University Of Ljubljana', 'start_date': 'July 2008', 'end_date': 'February 2011', 'degree': 'Master Of Science Msc Computer Science'}, {'institution': 'University Of Ljubljana', 'start_date': 'September 2005', 'end_date': 'June 2008', 'degree': 'Bachelor Of Science Bsc Computer Science'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'January 2012', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science In Physics'}]
# list_dict = [{'institution': 'Universit Degli Studi Di Milano', 'start_date': 'October 2014', 'end_date': 'September 2018', 'degree': 'Bachelor Of Science In Psychology'}, {'institution': 'Bangor University', 'start_date': 'January 2017', 'end_date': 'June 2017', 'degree': 'Erasmus Semester'}]
# list_dict = [{'institution': 'Radboud University Nijmegen', 'start_date': 'September 2023', 'end_date': 'Currrent', 'degree': 'Msc Intelligent Technology'}, {'institution': 'Radboud University Nijmegen', 'start_date': 'September 2019', 'end_date': 'July 2023', 'degree': 'Bsc Artificial Intelligence'}]
# ...
# list_dict = [{'institution': 'Sapienza University', 'start_date': 'October 2013', 'end_date': 'March 2016', 'degree': 'Masters Degree in Media Studies and Digital Communication'}, {'institution': 'Humboldt university Berlin', 'start_date': 'January 2009', 'end_date': 'December 2012', 'degree': 'Bachelor Of Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Nust School Of Electrical Engineering And Computer Science', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Faculty Of Letters And Philosophy', 'start_date': 'September 2010', 'end_date': 'July 2013', 'degree': 'Bachelors Degree in Humanistiic Studies'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Nust School Of Electrical Engineering And Computer Science', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Nust School Of Electrical Engineering And Computer Science', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Universidad De Alcala De Henares', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Universidad De Alcala De Henares', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}, {'institution': 'Memorial University Newfoundland', 'start_date': 'January 2019', 'end_date': 'April 2019', 'degree': 'Exchange Semester'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'University College London Ucl', 'start_date': 'January 2022', 'end_date': 'December 2022', 'degree': 'Masters In It Project Management'}, {'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Hassoplattnerinstitute University Potsdam', 'start_date': 'January 2016', 'end_date': 'December 2019', 'degree': 'Master Of Science Computer Science'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'International University Of La Rioja', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Goethe University Frankfurt', 'start_date': 'October 2016', 'end_date': 'September 2020', 'degree': 'Msc Business Informatics'}, {'institution': 'Ottovonguericke University Magdeburg', 'start_date': 'January 2011', 'end_date': 'December 2015', 'degree': 'Bachelor Of Science Computer Science'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# list_dict = [{'institution': 'Uned', 'start_date': 'January 2018', 'end_date': 'December 2019', 'degree': 'Master In Teaching Spanish As A Second Language'}, {'institution': 'Alejandro De Humboldt University', 'start_date': 'January 2006', 'end_date': 'December 2011', 'degree': 'Higher Computer Engineering'}]
# list_dict = [{'institution': 'Polytechnic University Of Madrid Upm', 'start_date': 'September 2017', 'end_date': 'August 2023', 'degree': "Bachelor's Degree in Information Society Technologies"}]
# /Users/mastropi/anaconda3/envs/findhr2/lib/python3.11/site-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# array([0.45328752, 0.44748211, 0.45328752, ..., 0.45328752, 0.46784556,
#        0.42921962])

# %%
# Metadata at the end of the first phase of the pipeline.
# See the metadata generated for the derived columns (last three ones).
